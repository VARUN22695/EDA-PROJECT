# %% [markdown]
# # VIRAT KOHLI CENTURY ANALYSIS

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('virat.jpg')
plt.imshow(img)
plt.axis('off')  
plt.show()

# %% [markdown]
# DATA INGESTION

# %%
import pandas as pd
df=pd.read_csv("Virat-Kohli-International-Cricket-Centuries.csv")
df
# Out:
#     No.   Runs       Against  Position  Innings  \
# 0     1    107     Sri Lanka         4        2
# 1     2  102*     Bangladesh         3        2
# 2     3    118     Australia         3        2
# 3     4    105   New Zealand         3        1
# 4     5   100*    Bangladesh         4        1
# ..  ...    ...           ...       ...      ...
# 75   76    121   West Indies         4        1
# 76   77   122*      Pakistan         3        1
# 77   78   103*    Bangladesh         3        2
# 78   79   101*  South Africa         3        1
# 79   80    117   New Zealand         3        1
#
#                                             Venue   Ground       Date Result
# 0                           Eden Gardens, Kolkata     Home  24-Dec-09    Won
# 1            Sher-e-Bangla Cricket Stadium, Dhaka     Away  11-Jan-10    Won
# 2                APCA-VDCA Stadium, Visakhapatnam     Home  20-Oct-10    Won
# 3                         Nehru Stadium, Guwahati     Home  28-Nov-10    Won
# ...

# %% [markdown]
# DATA CLEANING

# %%
import copy
dc= copy.deepcopy(df)

# %%
df["Runs"]=df["Runs"].str.strip()
df["Against"]=df["Against"].str.strip()

# %%
print(df["Runs"].unique())
print(df["Against"].unique())
print(df["Position"].unique())
print(df["Innings"].unique())
print(df["Venue"].unique())
print(df["Ground"].unique())
print(df["Date"].unique())
print(df["Result"].unique())
# Out:
# ['107' '102*' '118' '105' '100*' '112*' '117' '116' '133*' '108' '183'
#  '106' '128*' '103' '102' '115' '115*' '119' '123' '105*' '136' '127'
#  '139*' '141' '169' '147' '138' '200' '211' '154*' '167' '235' '122' '204'
#  '111*' '103*' '131' '110*' '121' '113' '104*' '213' '243' '153' '112'
#  '160*' '129*' '149' '139' '140' '157*' '104' '120' '114*' '254*' '122*'
#  '166*' '186' '101*']
# ['Sri Lanka' 'Bangladesh' 'Australia' 'New Zealand' 'England'
#  'West Indies' 'Pakistan' 'Zimbabwe' 'South Africa' 'Afghanistan']
# [4 3 6 5 2]
# [2 1 4 3]
# ['Eden Gardens, Kolkata' 'Sher-e-Bangla Cricket Stadium, Dhaka'
#  'APCA-VDCA Stadium, Visakhapatnam' 'Nehru Stadium, Guwahati'
#  'Sophia Gardens, Cardiff' 'Feroz Shah Kotla Ground, Delhi'
#  'Adelaide Oval, Adelaide' 'Bellerive Oval, Hobart'
#  'MRIC Stadium, Hambantota' 'R. Premadasa Stadium, Colombo'
#  'M. Chinnaswamy Stadium, Bangalore'
#  'Vidarbha Cricket Association Stadium, Nagpur'
# ...

# %%
df["Ground"].isna()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 75    False
# 76    False
# 77    False
# 78     True
# 79    False
# Name: Ground, Length: 80, dtype: bool

# %%
df.iloc[78,6]
# Out:
# nan

# %%
df.iloc[78,5]
# Out:
# 'Eden Gardens, Kolkata'

# %% [markdown]
# fill the na value with home

# %%
df.iloc[78,6]= "Home"

# %%
df["Ground"].unique()
# Out:
# array(['Home', 'Away', 'Neutral'], dtype=object)

# %% [markdown]
# DATA ANALYSIS

# %%
df
# Out:
#     No.  Runs       Against  Position  Innings  \
# 0     1   107     Sri Lanka         4        2
# 1     2  102*    Bangladesh         3        2
# 2     3   118     Australia         3        2
# 3     4   105   New Zealand         3        1
# 4     5  100*    Bangladesh         4        1
# ..  ...   ...           ...       ...      ...
# 75   76   121   West Indies         4        1
# 76   77  122*      Pakistan         3        1
# 77   78  103*    Bangladesh         3        2
# 78   79  101*  South Africa         3        1
# 79   80   117   New Zealand         3        1
#
#                                             Venue   Ground       Date Result
# 0                           Eden Gardens, Kolkata     Home  24-Dec-09    Won
# 1            Sher-e-Bangla Cricket Stadium, Dhaka     Away  11-Jan-10    Won
# 2                APCA-VDCA Stadium, Visakhapatnam     Home  20-Oct-10    Won
# 3                         Nehru Stadium, Guwahati     Home  28-Nov-10    Won
# ...

# %% [markdown]
# WIN-LOSS PERCENTAGE ANALYSIS

# %%
df["Result"].value_counts()
# Out:
# Won           55
# Lost          13
# Drawn          9
# Lost (D/L)     1
# Won (D/L)      1
# Tied           1
# Name: Result, dtype: int64

# %%
Win_percentage= (56/80)*100
print(Win_percentage)
loss_percentage=(14/80)*100
print(loss_percentage)
Draw_Tie_percentage=(10/80)*100
print(Draw_Tie_percentage)
# Out:
# 70.0
# 17.5
# 12.5

# %% [markdown]
# INFERENCE:- TEAM INDIA HAS WON 70 PERCENTAGE OF THE MATCHES WHEN KOHLI SCORED A CENTURY AND LOST ONLY 17.5 PERCENTAGE OF TIMES

# %% [markdown]
# DATE SIGNIFICANCE

# %%
df["Date"].value_counts()
# Out:
# 09-Dec-14    2
# 24-Dec-09    1
# 15-Jan-17    1
# 04-Oct-18    1
# 18-Aug-18    1
#             ..
# 17-Oct-14    1
# 26-Feb-14    1
# 14-Feb-14    1
# 19-Jan-14    1
# 15-Nov-23    1
# Name: Date, Length: 79, dtype: int64

# %% [markdown]
# INFERENCE:- THERE IS NO PARTICULAR DATA SIFNIFICANCE AS EXCEPT FOR ONE TIME KOHLI HAS GOT CENTURIES IN ALL DIFFERENT DATES

# %% [markdown]
# HOME-AWAY ANALYSIS

# %%
df["Ground"].value_counts()
# Out:
# Home       38
# Away       36
# Neutral     6
# Name: Ground, dtype: int64

# %% [markdown]
# INFERENCE:- KOHLI HAS MORE AWAY AND NEUTRAL VENUE CENTURIES THAN HOME GROUND CENTURIES

# %% [markdown]
# FAVOURITE VENUES

# %%
df["Venue"].value_counts()
# Out:
# Adelaide Oval, Adelaide                                  5
# Eden Gardens, Kolkata                                    4
# R. Premadasa Stadium, Colombo                            4
# Sher-e-Bangla Cricket Stadium, Dhaka                     4
# Queen's Park Oval, Port of Spain                         4
# Maharashtra Cricket Association Stadium, Pune            3
# Vidarbha Cricket Association Stadium, Nagpur             3
# Wankhede Stadium, Mumbai                                 3
# JSCA International Stadium, Ranchi                       2
# APCA-VDCA Stadium, Visakhapatnam                         2
# Feroz Shah Kotla Ground, Delhi                           2
# M. A. Chidambaram Stadium, Chennai                       2
# ACA Stadium, Guwahati                                    2
# ACA-VDCA Cricket Stadium, Visakhapatnam                  2
# Galle International Stadium, Galle                       2
# Melbourne Cricket Ground, Melbourne                      2
# ...

# %% [markdown]
# CENTURIES VS OPPOSITION

# %%
df["Against"].value_counts()
# Out:
# Australia       16
# Sri Lanka       15
# West Indies     12
# New Zealand      9
# England          8
# South Africa     8
# Bangladesh       7
# Pakistan         3
# Zimbabwe         1
# Afghanistan      1
# Name: Against, dtype: int64

# %% [markdown]
# INFERENCE:- KOHLI HAS SCORED MOST CENTURIES AGAINST AUSTRALIA AND ALSO THE DATA SHOWS THAT HE LOVES TO SCORE AGAINST STRONG TEAMS AND HE HAS LESS CENTURIES AGAINST COMPARATIVELY WEAKER TEAMS ONE OF THE REASON IS BECAUSE HE HAS NOT PLAYED MANY MATCHES AGAINST THEM

# %% [markdown]
# CENTURIES AT DIFFERENT INNINGS OF A MATCH

# %%
df["Innings"].value_counts()
# Out:
# 2    42
# 1    33
# 3     3
# 4     2
# Name: Innings, dtype: int64

# %% [markdown]
# INFERENCE:- KOHLI HAS 46 CENTURIES BATTING AT 2ND ,3RD AND 4TH INNINGS WHICH IS A RECORD

# %%
df["Position"].value_counts()
# Out:
# 3    43
# 4    32
# 5     3
# 6     1
# 2     1
# Name: Position, dtype: int64

# %% [markdown]
# SCORES

# %%
centuries_filtered=df[df["Runs"]>="150"]

# %%
centuries_filtered
# Out:
#     No.  Runs       Against  Position  Innings  \
# 11   12   183      Pakistan         3        2
# 29   30   169     Australia         4        2
# 36   37   200   West Indies         4        1
# 37   38   211   New Zealand         4        1
# 38   39  154*   New Zealand         3        2
# 39   40   167       England         4        1
# 40   41   235       England         4        2
# 42   43   204    Bangladesh         4        1
# 50   51   213     Sri Lanka         4        2
# 51   52   243     Sri Lanka         4        1
# 52   53   153  South Africa         4        2
# 54   55  160*  South Africa         3        1
# 60   61  157*   West Indies         3        1
# 68   69  254*  South Africa         4        1
# 73   74  166*     Sri Lanka         3        1
# 74   75   186     Australia         4        2
#
#                                                 Venue   Ground       Date  \
# 11               Sher-e-Bangla Cricket Stadium, Dhaka  Neutral  18-Mar-12
# ...

# %%
centuries_filtered.count()
# Out:
# No.         16
# Runs        16
# Against     16
# Position    16
# Innings     16
# Venue       16
# Ground      16
# Date        16
# Result      16
# dtype: int64

# %%
centuries_filtered["Result"].value_counts()
# Out:
# Won      11
# Drawn     3
# Lost      1
# Tied      1
# Name: Result, dtype: int64

# %%
Win_percentage1= (11/16)*100
print(Win_percentage1)
loss_percentage1=(1/16)*100
print(loss_percentage1)
Draw_Tie_percentage1=(4/16)*100
print(Draw_Tie_percentage1)
# Out:
# 68.75
# 6.25
# 25.0

# %% [markdown]
# INFERENCE:- KOHLI HAS SCORED 150 AND 150+ SCORES 16 TIMES OUT OF 80 AND HE HAS WON 68.75% OF THESE MATCHES AND LOST ONLY 6.25% OF THE MATCHES.. THE WIN PERCENTAGE HAS DECREASED COMPARED TO 100+ BECAUSE OF MORE DATA COMING FROM THE TEST MATCHES AND ALSO IT SIGNIFIES THAT HE HAS SCORED RUNS WHEN OTHERS FROM THE TEAM FAILED.
